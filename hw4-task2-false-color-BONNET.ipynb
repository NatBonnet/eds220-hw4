# %%
import os
import numpy as np
import pandas as pd
import xarray as xr

landsat = xr.open_dataset('landsat8-2025-02-23-palisades-eaton.nc', engine="netcdf4")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 6
#       3 import pandas as pd
#       4 import xarray as xr
# ----> 6 landsat = xr.open_dataset('landsat8-2025-02-23-palisades-eaton.nc', engine="netcdf4")
#
# File c:\Users\oc3an\.conda\envs\eds220-env\Lib\site-packages\xarray\backends\api.py:657, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     654 if from_array_kwargs is None:
#     655     from_array_kwargs = {}
# --> 657 backend = plugins.get_backend(engine)
#     659 decoders = _resolve_decoders_kwargs(
#     660     decode_cf,
#     661     open_backend_dataset_parameters=backend.open_dataset_parameters,
# ...
